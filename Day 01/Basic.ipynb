# %%
name="Nancy"
age=25
a=15
b=22
print(name)
print(age)
print(a+b)
# Out:
# Nancy
# 25
# 37 -7

# %%
print("Student report")
print("******************")
name="Sasmitha Sudusinghe"
print(name)
age=23
print(age)
print("******************")
m1=83
print("Maths:-",m1)
m2=75
print("Science:-",m2)
m3=93
print("IT:-",m3)
total=m1+m2+m3
print("Total:-",total)
avg=total/3
print("Average:-",avg)
print("******************")
# Out:
# Student report
# ******************
# Sasmitha Sudusinghe
# 23
# ******************
# Maths:- 83
# Science:- 75
# IT:- 93
# Total:- 251
# Average:- 83.66666666666667
# ******************
